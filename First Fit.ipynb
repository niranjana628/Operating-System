# %%
def add(m,n):
    c=m+n
    return c
a=float(input('number 1='))
b=float(input('number 2='))
print('sum=',add(a,b))
# Out:
# number 1=34.4
# number 2=33.6
# sum= 68.0

# %% [markdown]
# ### First Fit

# %%
def firstFit(blockSize, m, processSize, n):
     
    # Stores block id of the
    # block allocated to a process
    allocation = [-1] * n
 
    # Initially no block is assigned to any process
 
    # pick each process and find suitable blocks
    # according to its size ad assign to it
    

    
    for i in range(n):
        for j in range(m):
            if blockSize[j] >= processSize[i]:
                 
                # allocate block j to p[i] process
                allocation[i] = j
 
                # replacing taken block size with zero
                blockSize[j]=0
 
                break
 
    print(" Process No. Process Size      Block no.")
    for i in range(n):
        print(" ", i + 1, "         ", processSize[i],
                          "         ", end = " ")
        if allocation[i] != -1:
            print(allocation[i] + 1)
        else:
            print("Not Allocated")
 
# Driver code
if __name__ == '__main__':
    blockSize = []
    
    processSize = []
    bsize=int(input('enter number of blocks'))
    psize=int(input('enter number of processes'))
    for i in range(bsize):
        b=int(input('Enter block size:'))
        blockSize.append(b)
    for j in range(psize):
        p=int(input('Enter process size:'))
        processSize.append(p)
 
    firstFit(blockSize, bsize, processSize, psize)
# Out:
# enter number of blocks5
# enter number of processes4
# Enter block size:100
# Enter block size:500
# Enter block size:200
# Enter block size:300
# Enter block size:600
# Enter process size:212
# Enter process size:417
# Enter process size:112
# Enter process size:426
#  Process No. Process Size      Block no.
#   1           212           2
#   2           417           5
#   3           112           3
#   4           426           Not Allocated

# %%
def firstFit(blockSize, m, processSize, n):
     
    # Stores block id of the
    # block allocated to a process
    allocation = [-1] * n
 
    # Initially no block is assigned to any process
 
    # pick each process and find suitable blocks
    # according to its size ad assign to it
    

    temp=[]
    for i in range(n):
        for j in range(m):
            if blockSize[j] >= processSize[i]:
                a=blockSize[j] - processSize[i]:
                temp.append(a)
    
    
     
    
    print(" Process No. Process Size      Block no.")
    for i in range(n):
        print(" ", i + 1, "         ", processSize[i],
                          "         ", end = " ")
        if allocation[i] != -1:
            print(allocation[i] + 1)
        else:
            print("Not Allocated")
 
# Driver code
if __name__ == '__main__':
    blockSize = []
    
    processSize = []
    bsize=int(input('enter number of blocks'))
    psize=int(input('enter number of processes'))
    for i in range(bsize):
        b=int(input('Enter block size:'))
        blockSize.append(b)
    for j in range(psize):
        p=int(input('Enter process size:'))
        processSize.append(p)
 
    firstFit(blockSize, bsize, processSize, psize)
# Out:
#   Input In [9]
#     a=blockSize[j] - processSize[i]:
#                                    ^
# SyntaxError: invalid syntax

# %%
def firstFit(blockSize, m, processSize, n):
     
    # Stores block id of the
    # block allocated to a process
    allocation = [-1] * n
 
    # Initially no block is assigned to any process
 
    # pick each process and find suitable blocks
    # according to its size ad assign to it
    
    diff=0
    temp=[]
    for i in range(n):
        for j in range(m):
            if blockSize[j] >= processSize[i]:
                diff=blockSize[j] - processSize[i]
                temp.append(diff)
                if 
                 
                
                
        
 
    print(" Process No. Process Size      Block no.")
    for i in range(n):
        print(" ", i + 1, "         ", processSize[i],
                          "         ", end = " ")
        if allocation[i] != -1:
            print(allocation[i] + 1)
        else:
            print("Not Allocated")
 
# Driver code
if __name__ == '__main__':
    blockSize = []
    
    processSize = []
    bsize=int(input('enter number of blocks'))
    psize=int(input('enter number of processes'))
    for i in range(bsize):
        b=int(input('Enter block size:'))
        blockSize.append(b)
    for j in range(psize):
        p=int(input('Enter process size:'))
        processSize.append(p)
 
    firstFit(blockSize, bsize, processSize, psize)
